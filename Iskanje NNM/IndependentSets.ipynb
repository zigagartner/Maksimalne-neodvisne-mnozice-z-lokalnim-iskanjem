# %%
H = graphs.CubeGraph(4)

# %%
plot(H)
# Out:
# Graphics object consisting of 49 graphics primitives

# %%
from sage.graphs.independent_sets import IndependentSets

# %%
I = IndependentSets(H)
list(I)
# Out:
# [['1101'],
#  ['1101', '0000'],
#  ['1101', '0000', '0111'],
#  ['1101', '0000', '0111', '1010'],
#  ['1101', '0000', '0111', '1110'],
#  ['1101', '0000', '0111', '1110', '1011'],
#  ['1101', '0000', '0111', '1011'],
#  ['1101', '0000', '0011'],
#  ['1101', '0000', '0011', '1010'],
#  ['1101', '0000', '0011', '1010', '0110'],
#  ['1101', '0000', '0011', '1110'],
#  ['1101', '0000', '0011', '0110'],
#  ['1101', '0000', '1010'],
#  ['1101', '0000', '1010', '0110'],
#  ['1101', '0000', '1110'],
#  ['1101', '0000', '1110', '1011'],
#  ['1101', '0000', '0110'],
#  ['1101', '0000', '0110', '1011'],
#  ['1101', '0000', '1011'],
#  ['1101', '0001'],
#  ['1101', '0001', '0111'],
#  ['1101', '0001', '0111', '0010'],
#  ['1101', '0001', '0111', '0010', '1000'],
#  ['1101', '0001', '0111', '0010', '1000', '1110'],
#  ['1101', '0001', '0111', '0010', '1000', '1110', '0100'],
#  ['1101', '0001', '0111', '0010', '1000', '1110', '0100', '1011'],
# ...

# %%
Max = IndependentSets(H, maximal=True)
list(Max)
# Out:
# [['1101', '0000', '0111', '1010'],
#  ['1101', '0000', '0111', '1110', '1011'],
#  ['1101', '0000', '0011', '1010', '0110'],
#  ['1101', '0000', '0011', '1110'],
#  ['1101', '0000', '0110', '1011'],
#  ['1101', '0001', '0111', '0010', '1000', '1110', '0100', '1011'],
#  ['1101', '0001', '0111', '1010', '0100'],
#  ['1101', '0001', '1000', '0110', '1011'],
#  ['1101', '0001', '1010', '0110'],
#  ['1101', '0011', '1000', '1110', '0100'],
#  ['1101', '0011', '1000', '0110'],
#  ['1101', '0011', '1010', '0100'],
#  ['0000', '0111', '1010', '1100', '1001'],
#  ['0000', '0111', '1100', '1011'],
#  ['0000', '0111', '1110', '1001'],
#  ['0000', '0101', '0011', '1010', '1100', '1111', '0110', '1001'],
#  ['0000', '0101', '0011', '1110', '1001'],
#  ['0000', '0101', '1100', '0110', '1011'],
#  ['0000', '0101', '1110', '1011'],
#  ['0001', '0111', '0010', '1100', '1011'],
#  ['0001', '0111', '1010', '1100'],
#  ['0001', '0010', '1000', '1111', '0100'],
#  ['0001', '0010', '1100', '1111'],
# ...

# %%
pl = H.graphplot(vertex_colors={"#FF0000":['0111', '0001', '1000', '1011', '0010', '1101', '1110', '0100']})
pl.show()
# Out:
# Graphics object consisting of 49 graphics primitives
