# %%
G = graphs.CubeGraph(6)
G.show()
G.vertices()
# Out:
# Graphics object consisting of 257 graphics primitives
# ['000000',
#  '000001',
#  '000010',
#  '000011',
#  '000100',
#  '000101',
#  '000110',
#  '000111',
#  '001000',
#  '001001',
#  '001010',
#  '001011',
#  '001100',
#  '001101',
#  '001110',
#  '001111',
#  '010000',
#  '010001',
#  '010010',
#  '010011',
#  '010100',
#  '010101',
#  '010110',
#  '010111',
#  '011000',
#  '011001',
#  '011010',
#  '011011',
#  '011100',
#  '011101',
#  '011110',
#  '011111',
#  '100000',
#  '100001',
#  '100010',
#  '100011',
#  '100100',
#  '100101',
#  '100110',
#  '100111',
#  '101000',
#  '101001',
#  '101010',
#  '101011',
#  '101100',
#  '101101',
#  '101110',
#  '101111',
#  '110000',
#  '110001',
#  '110010',
#  '110011',
#  '110100',
#  '110101',
#  '110110',
#  '110111',
#  '111000',
#  '111001',
#  '111010',
#  '111011',
#  '111100',
#  '111101',
#  '111110',
#  '111111']

# %%
p = MixedIntegerLinearProgram(maximization=True)
x = p.new_variable(binary=True)
p.set_objective(sum(x[v] for v in G))

for u, v in G.edges(labels=False):
    p.add_constraint(x[u] + x[v] <= 1)
    
p.solve()
x = p.get_values(x)
CLP_najvecja_neodvisna_mnozica = [v for v, i in x.items() if i]
#print(CLP_najvecja_neodvisna_mnozica)
list(v for v in CLP_najvecja_neodvisna_mnozica)
# Out:
# ['010010',
#  '110000',
#  '110110',
#  '011011',
#  '100100',
#  '001001',
#  '010111',
#  '011000',
#  '100111',
#  '011110',
#  '011101',
#  '111100',
#  '110011',
#  '000110',
#  '001111',
#  '101101',
#  '001100',
#  '000011',
#  '111111',
#  '100001',
#  '111010',
#  '101000',
#  '010100',
#  '000101',
#  '100010',
#  '001010',
#  '010001',
#  '111001',
#  '110101',
#  '101011',
#  '101110',
#  '000000']

# %%
pl = G.graphplot(vertex_colors={"#FF0000":list(v for v in CLP_najvecja_neodvisna_mnozica)})
pl.show()
# Out:
# Graphics object consisting of 257 graphics primitives
